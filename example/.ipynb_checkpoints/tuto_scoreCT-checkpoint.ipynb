# %% [markdown]
# ## scoreCT: Automated cell type annotation in scRNA-seq data
# ScoreCT is a script allowing automated annotation of scRNA-seq data analyzed with Scanpy. Providing your own reference or using the reference regularly updated and provided with the package, you can automatically assign clusters from your Scanpy analysis pipeline to cell types.

# %% [markdown]
# ## Option 1: Using your own reference (CSV, TSV ...)
# Here, the user provide it's own csv as a reference. The wrangling and formating is left to the user as the reference table can take many different shapes. For an example, you can look at the file __ref_marker.csv__ used in this example.

# %%
# Import modules
import os
import sys
import pandas as pd
import scanpy.api as sc

sys.path.append('../src/')
import scorect as ct

# Load example scRNA-seq data (already analyzed)
adata = sc.read('../data/data.h5ad')

# Load reference table - the wrangling depends on your formating. For reading csv, tsv...
# Read Pandas documentation https://pandas.pydata.org/pandas-docs/stable/index.html
ref_marker = pd.read_csv('../data/ref_marker.csv', index_col=0, header=None).T
# Out:
# /Users/lucas/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# Wrangle results from existing sc.tl.rank_genes_groups() results
marker_df = ct.wrangle_ranked_genes(adata)
print(marker_df.head())
# Out:
# Number of markers used in ranked_gene_groups:  100
#      z_score      adj_pvals        gene  cluster_number
# 0  43.342510  3.071254e-232       MGST1               0
# 1  37.299587  1.603663e-192        PRTG               0
# 2  34.916588  5.225948e-183       NR2F1               0
# 3  29.018284  5.412440e-137       SFRP2               0
# 4  28.860355  4.856073e-136  AC018730.1               0

# %%
# Score cell types for each cluster
dict_scores = ct.score_clusters(marker_df, nb_marker=100, bin_size=20, user_ref=ref_marker)
# Print a summary of scoring (optional)
ct.scoring_summary(dict_scores)
# Out:
# Rows: Cell types / Columns: Clusters
# <style  type="text/css" >
#     #T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col8 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row2_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row2_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row3_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row3_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row4_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row4_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row5_col0 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row5_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row5_col6 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row5_col11 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row5_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row5_col17 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row6_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row6_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row7_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row7_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row7_col16 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row8_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row8_col15 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col1 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col2 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col3 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col4 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col5 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col7 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col9 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col10 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col12 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col13 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col14 {
#             background-color:  yellow;
#         }    #T_054da438_1373_11e9_a7c8_1c36bb123fd6row9_col15 {
#             background-color:  yellow;
#         }</style>
# <table id="T_054da438_1373_11e9_a7c8_1c36bb123fd6" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_054da438_1373_11e9_a7c8_1c36bb123fd6level0_row0" class="row_heading level0 row0" >Astrocytes</th>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col0" class="data row0 col0" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col1" class="data row0 col1" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col2" class="data row0 col2" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col3" class="data row0 col3" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col4" class="data row0 col4" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col5" class="data row0 col5" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col6" class="data row0 col6" >2</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col7" class="data row0 col7" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col8" class="data row0 col8" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col9" class="data row0 col9" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col10" class="data row0 col10" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col11" class="data row0 col11" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col12" class="data row0 col12" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col13" class="data row0 col13" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col14" class="data row0 col14" >4</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col15" class="data row0 col15" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col16" class="data row0 col16" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row0_col17" class="data row0 col17" >2</td>
#     </tr>    <tr>
#         <th id="T_054da438_1373_11e9_a7c8_1c36bb123fd6level0_row1" class="row_heading level0 row1" >Cajal-Retzius Neurons</th>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col0" class="data row1 col0" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col1" class="data row1 col1" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col2" class="data row1 col2" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col3" class="data row1 col3" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col4" class="data row1 col4" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col5" class="data row1 col5" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col6" class="data row1 col6" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col7" class="data row1 col7" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col8" class="data row1 col8" >14</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col9" class="data row1 col9" >0</td>
#         <td id="T_054da438_1373_11e9_a7c8_1c36bb123fd6row1_col10" class="data row1 col10" >0</td>
#         <td id="T_054da4

# %%
# Assign cell types if possible : ties are labelled as NA
ct.assign_celltypes(adata, dict_scores)
# Visualize results thanks to Scanpy tSNE tool
sc.pl.tsne(adata, color='Assigned type')
# Out:
# ... storing 'Assigned type' as categorical

# %% [markdown]
# ## Option 2: Use large reference files (WIP)
# Here, the user has to specify the path where the large reference file is (described in the README). These files are TSV files organized and labeled by species (_eg: human.tsv_), with various features like organ and context. Right now, only one field is supported for each arguments (in the future, we would like to be able to mix several organs and contexts). The big reference file is automatically parsed to keep relevant genes/cell types to your data. </br>
#
# The rest of the procedure is similar to Option 1.

# %%
# Using provided template: large reference (only template at the time)
# Load example data again
adata2 = sc.read('../data/data.h5ad')
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# Wrangle results from existing sc.tl.rank_genes_groups() results
marker_df = ct.wrangle_ranked_genes(adata)
print(marker_df.head())
# Out:
# Number of markers used in ranked_gene_groups:  100
#      z_score      adj_pvals        gene  cluster_number
# 0  43.342510  3.071254e-232       MGST1               0
# 1  37.299587  1.603663e-192        PRTG               0
# 2  34.916588  5.225948e-183       NR2F1               0
# 3  29.018284  5.412440e-137       SFRP2               0
# 4  28.860355  4.856073e-136  AC018730.1               0

# %%
# Score cell types for each cluster
# If context is None, default context is set to 'healthy'
dict_scores = ct.score_clusters(marker_df, nb_marker=100, path='../data/',
                                species='human', organ='brain', context=None,
                                comments=False, bin_size=20)
# Print a summary of scoring
ct.scoring_summary(dict_scores)
# Out:
# Rows: Cell types / Columns: Clusters
# <style  type="text/css" >
#     #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col0 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col1 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col2 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col3 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col4 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col5 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col6 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col7 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col8 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col9 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col10 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col11 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col12 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col13 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col14 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col15 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col16 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col17 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col0 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col2 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col4 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col5 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col6 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col7 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col9 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col10 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col11 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col12 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col13 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col14 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col15 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col16 {
#             background-color:  yellow;
#         }    #T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col17 {
#             background-color:  yellow;
#         }</style>
# <table id="T_05fba970_1373_11e9_a159_1c36bb123fd6" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_05fba970_1373_11e9_a159_1c36bb123fd6level0_row0" class="row_heading level0 row0" >IPC</th>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col0" class="data row0 col0" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col1" class="data row0 col1" >4</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col2" class="data row0 col2" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col3" class="data row0 col3" >2</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col4" class="data row0 col4" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col5" class="data row0 col5" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col6" class="data row0 col6" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col7" class="data row0 col7" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col8" class="data row0 col8" >5</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col9" class="data row0 col9" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col10" class="data row0 col10" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col11" class="data row0 col11" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col12" class="data row0 col12" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col13" class="data row0 col13" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col14" class="data row0 col14" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col15" class="data row0 col15" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col16" class="data row0 col16" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row0_col17" class="data row0 col17" >0</td>
#     </tr>    <tr>
#         <th id="T_05fba970_1373_11e9_a159_1c36bb123fd6level0_row1" class="row_heading level0 row1" >Oligodendrocyte</th>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col0" class="data row1 col0" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col1" class="data row1 col1" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col2" class="data row1 col2" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col3" class="data row1 col3" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col4" class="data row1 col4" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col5" class="data row1 col5" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col6" class="data row1 col6" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col7" class="data row1 col7" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col8" class="data row1 col8" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col9" class="data row1 col9" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col10" class="data row1 col10" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col11" class="data row1 col11" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col12" class="data row1 col12" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123fd6row1_col13" class="data row1 col13" >0</td>
#         <td id="T_05fba970_1373_11e9_a159_1c36bb123

# %%
# Assign cell types if possible : ties are labelled as NA
ct.assign_celltypes(adata2, dict_scores)
# Visualize results thanks to Scanpy tSNE tool
sc.pl.tsne(adata2, color='Assigned type')
# Out:
# ... storing 'Assigned type' as categorical
